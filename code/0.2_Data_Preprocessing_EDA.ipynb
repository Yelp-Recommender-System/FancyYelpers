# %% [markdown]
# # Yelp data EDA - Xinli

# %%
import json
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## 1. Data loading

# %% [markdown]
# ### loading bussiness data

# %%
bus_df = pd.read_json('yelp_dataset/yelp_academic_dataset_business.json',orient='records',lines=True)
bus_df.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2  -73.580070    5.0             5        1
# ...

# %%
attributes = bus_df['attributes'].apply(pd.Series)
hours = bus_df['hours'].apply(pd.Series)

# %%
bus_df = pd.concat([bus_df.drop(['attributes','hours'],1),attributes,hours],axis=1)
bus_df.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  ...  AgesAllowed  \
# 0  -80.852612    3.5            36  ...          NaN
# 1 -111.890264    5.0             4  ...          NaN
# ...

# %%
bus_df[bus_df['categories'].notnull()]['categories']
# Out:
# 0         Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1         Health & Medical, Fitness & Instruction, Yoga,...
# 2                          Pets, Pet Services, Pet Groomers
# 3         Hardware Stores, Home Services, Building Suppl...
# 4         Home Services, Plumbing, Electricians, Handyma...
#                                 ...
# 209388                    Japanese, Sushi Bars, Restaurants
# 209389    Department Stores, Food, Mobile Phones, Fashio...
# 209390    American (New), Food, Burgers, Restaurants, Fa...
# 209391                     Pet Services, Pet Training, Pets
# 209392    Tax Services, Professional Services, Accountan...
# Name: categories, Length: 208869, dtype: object

# %%
bus_df.to_csv('business_df_cleaned.csv')

# %%
bus_df = pd.read_csv('business_df_cleaned.csv',index_col=0)
bus_df.head()
# Out:
# /Users/guxinli/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (50,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# ...

# %% [markdown]
# remove businesses whose ``categories`` is null

# %%
bus_df = bus_df[bus_df['categories'].notnull()]

# %%
bus_df.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  ...  AgesAllowed  \
# 0  -80.852612    3.5            36  ...          NaN
# 1 -111.890264    5.0             4  ...          NaN
# ...

# %%
bus_df['categories'] = bus_df['categories'].apply(lambda x: x.split(', '))
bus_df['categories']
# Out:
# 0         [Active Life, Gun/Rifle Ranges, Guns & Ammo, S...
# 1         [Health & Medical, Fitness & Instruction, Yoga...
# 2                        [Pets, Pet Services, Pet Groomers]
# 3         [Hardware Stores, Home Services, Building Supp...
# 4         [Home Services, Plumbing, Electricians, Handym...
#                                 ...
# 209388                  [Japanese, Sushi Bars, Restaurants]
# 209389    [Department Stores, Food, Mobile Phones, Fashi...
# 209390    [American (New), Food, Burgers, Restaurants, F...
# 209391                   [Pet Services, Pet Training, Pets]
# 209392    [Tax Services, Professional Services, Accounta...
# Name: categories, Length: 208869, dtype: object

# %%
x1 = bus_df['categories'][209391]
x1 = ['']+x1
x1
# Out:
# ['', 'Pet Services', 'Pet Training', 'Pets']

# %% [markdown]
# ### loading review data

# %%
#adopting methods from website
line_count = len(open("yelp_dataset/yelp_academic_dataset_review.json").readlines())
user_ids, business_ids, stars, dates, texts = [], [], [], [], []
with open("yelp_dataset/yelp_academic_dataset_business.json") as f:
    for line in tqdm(f, total=line_count):
        blob = json.loads(line)
        user_ids += [blob["user_id"]]
        business_ids += [blob["business_id"]]
        stars += [blob["stars"]]
        dates += [blob["date"]]
        texts += [blob["text"]]
ratings_ = pd.DataFrame(
    {"user_id": user_ids, "business_id": business_ids, "rating": stars, "date": dates, "text": texts}
)
# Out:
#   0%|          | 0/8021122 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-3e2760b43ad8> in <module>
#       5     for line in tqdm(f, total=line_count):
#       6         blob = json.loads(line)
# ----> 7         user_ids += [blob["user_id"]]
#       8         business_ids += [blob["business_id"]]
#       9         stars += [blob["stars"]]
#
# KeyError: 'user_id'
